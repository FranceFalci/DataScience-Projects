# %%
from google.colab import drive
import os

# 1. Conectamos Google Drive
drive.mount('/content/drive')

project_path = '/content/drive/MyDrive/run_projects/'

try:
    os.chdir(project_path)
    print(f"✅ ¡Éxito! Ahora estamos trabajando dentro de: {os.getcwd()}")
except FileNotFoundError:
    print("❌ No encontré la carpeta. Verifica el nombre en tu Google Drive.")
# Out:
# Mounted at /content/drive
# ✅ ¡Éxito! Ahora estamos trabajando dentro de: /content/drive/MyDrive/run_projects

# %%
# El signo ! es obligatorio para instalar cosas en Colab
# !pip install ultralytics mlflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 116.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 116.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 kB 63.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 23.8 MB/s eta 0:00:00
# ...

# %%
# !ls ./xrays_evaluation/src/training/train
# Out:
# experiment_benchmark.py  __init__.py  pretrained_models  train_baseline.py

# %%
# !python ./xrays_evaluation/src/training/train/train_baseline.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 🚀 Iniciando entrenamiento Baseline con yolo11n-cls...
# ...

# %%
# !mlflow ui --backend-store-uri sqlite:///src/training/train/mlflow.db
# Out:
# /bin/bash: line 1: mlflow: command not found

# %%
# !ls datasets/
# Out:
# data.rar
# german_credit_risk.csv
# german_credit_risk.csv.dvc
# ingeniia_services_xrays_evaluation_img_v1.0.0_training_20251121
# ingeniia_services_xrays_evaluation_img_v1.0.0_training_20251121.dvc
